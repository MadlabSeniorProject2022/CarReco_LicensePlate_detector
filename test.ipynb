# %%
# !python detect.py --weights LPD100x.pt --conf 0.75 --img-size 1280 --source src/ --name only_lp --crop
# Out:
# ^C
# YOLOR  2022-9-16 torch 1.9.0+cu111 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8191.375MB)
#
# c:\Users\PPUNN\anaconda3\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients, 103.2 GFLOPS
# Namespace(weights=['LPD100x.pt'], source='src/', img_size=1280, conf_thres=0.75, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='only_lp', exist_ok=False, no_trace=False, crop=True)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# ...

# %%
# !python detect.py --weights LPD100x.pt --conf 0.75 --img-size 640 --source src/field_src/Black --name lp_test_640
# Out:
# ^C

# %%
# !python detect.py --weights LPD100x.pt --conf 0.75 --img-size 640 --source src/field_src/Black --name lp_black_640 --crop
# Out:
# Namespace(weights=['LPD100x.pt'], source='src/field_src/Black', img_size=640, conf_thres=0.75, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='lp_black_640', exist_ok=False, no_trace=False, crop=True)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# Done. (14.6ms) Inference, (3.7ms) NMS
# Done. (13.1ms) Inference, (0.0ms) NMS
# Done. (14.4ms) Inference, (1.5ms) NMS
# Done. (12.9ms) Inference, (0.0ms) NMS
# Done. (12.0ms) Inference, (1.0ms) NMS
# Done. (20.1ms) Inference, (0.0ms) NMS
# Done. (12.5ms) Inference, (0.0ms) NMS
# Done. (11.5ms) Inference, (0.0ms) NMS
# Done. (14.5ms) Inference, (0.0ms) NMS
# Done. (13.4ms) Inference, (0.0ms) NMS
# Done. (16.3ms) Inference, (0.0ms) NMS
# ...

# %%
# !python detect.py --weights LPD100x.pt --conf 0.75 --img-size 640 --source src/field_src/Black/ --name lp_black_640 --crop
# Out:
# Namespace(weights=['LPD100x.pt'], source='src/field_src/Black/', img_size=640, conf_thres=0.75, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='lp_black_640', exist_ok=False, no_trace=False, crop=True)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!
#
# Done. (12.5ms) Inference, (0.0ms) NMS
# Done. (12.0ms) Inference, (1.4ms) NMS
# Done. (20.0ms) Inference, (1.0ms) NMS
# Done. (14.5ms) Inference, (0.0ms) NMS
# Done. (15.6ms) Inference, (1.0ms) NMS
# Done. (12.2ms) Inference, (0.0ms) NMS
# Done. (13.0ms) Inference, (0.0ms) NMS
# Done. (18.5ms) Inference, (0.0ms) NMS
# Done. (11.0ms) Inference, (1.0ms) NMS
# Done. (12.0ms) Inference, (0.0ms) NMS
# Done. (17.5ms) Inference, (0.0ms) NMS
# ...

# %%
from lean_detect import UseModel

# %%
yolo = UseModel("LPD100x.pt", "")
# Out:
# YOLOR  2022-9-16 torch 1.9.0+cu111 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8191.375MB)
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# c:\Users\PPUNN\anaconda3\lib\site-packages\torch\nn\functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  ..\c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Model Summary: 314 layers, 36481772 parameters, 6194944 gradients, 103.2 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
#  model is traced!

# %%
import cv2

def to_crop (x, img, conf, cls):
    c1, c2 = (int(x[0]), int(x[1])), (int(x[2]), int(x[3]))
    print(c1, c2)
    print(type(img))
    crop_img = img[ int(x[1]) : int(x[3]), int(x[0]): int(x[2])]
    print(x)
    cv2.imwrite("./ok.png", crop_img)

# %%
yolo.detect("src/field_src/Black/", do_function=to_crop)
# Out:
# c:\Users\PPUNN\Documents\FinalProj\Yolo_img_detect_boilerplate\src\field_src\Black\use001-13938-1.png
# find
# (335, 85) (370, 187)
# <class 'numpy.ndarray'>
# [tensor(335., device='cuda:0', grad_fn=<UnbindBackward>), tensor(85., device='cuda:0', grad_fn=<UnbindBackward>), tensor(370., device='cuda:0', grad_fn=<UnbindBackward>), tensor(187., device='cuda:0', grad_fn=<UnbindBackward>)]
# c:\Users\PPUNN\Documents\FinalProj\Yolo_img_detect_boilerplate\src\field_src\Black\use001-13939-1.png
# c:\Users\PPUNN\Documents\FinalProj\Yolo_img_detect_boilerplate\src\field_src\Black\use001-13940-1.png
# c:\Users\PPUNN\Documents\FinalProj\Yolo_img_detect_boilerplate\src\field_src\Black\use001-13941-1.png
# c:\Users\PPUNN\Documents\FinalProj\Yolo_img_detect_boilerplate\src\field_src\Black\use001-13942-1.png
# c:\Users\PPUNN\Documents\FinalProj\Yolo_img_detect_boilerplate\src\field_src\Black\use001-13943-1.png
# find
# (51, 238) (80, 272)
# <class 'numpy.ndarray'>
# ...
